# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
plt.title("Epic Info")
plt.xlabel('X axis')
plt.ylabel('Y axis')
x=np.linspace(1,16,16)
y=[5,7,8,3,5,6,3,7,2,12,5,7,2,6,9,2]
plt.plot(x,y)
